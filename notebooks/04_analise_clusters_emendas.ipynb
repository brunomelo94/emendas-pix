# %% [markdown]
# # Análise das Emendas PIX com Clusters
#
# Este notebook carrega `data/dados_com_clusters.csv` e realiza as etapas descritas na metodologia do projeto:
# 1. *Exploração inicial*
# 2. *Modelagem OLS com efeitos fixos de partido*
# 3. *Modelagem multinível step-up*

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import statsmodels.api as sm

# %%
df = pd.read_csv("../data/dados_com_clusters.csv").dropna()
df = df[df["porcentagem_votos_validos_2024"] < 1]
df = df[df["emendas_pix_per_capita_partido_prefeito_eleito"] > 1000]
df.head()
# Out:
#                   municipio sigla_municipio prefeito_eleito_2024  \
# 1  ABADIA DOS DOURADOS - MG              MG                 CIRO
# 2            ABADIANIA - GO              GO            DR ITAMAR
# 3               ABAETE - MG              MG               IVANIR
# 4           ABAETETUBA - PA              PA  FRANCINETI CARVALHO
# 7                ABARE - BA              BA  EMANOEL DA FARMÁCIA
#
#   sigla_partido_prefeito_eleito  porcentagem_votos_validos_2024  \
# 1                           PSD                        0.575992
# 2                            PP                        0.619504
# 3                           MDB                        0.491826
# 4                           MDB                        0.417201
# 7                            PT                        0.823769
#
#    emendas_pix_per_capita_partido_prefeito_eleito  idhm_2010  \
# 1                                     3188.775510      0.689
# 2                                     3481.894150      0.689
# 3                                     1764.057332      0.698
# 4                                     2528.605204      0.628
# 7                                    21543.171382      0.575
#
#    alfabetizacao_2010  pib_per_capita_2021  densidade_demografica_2010  \
# 1               90.88         28184.630102                    7.127400
# 2               89.16         25842.850511                   16.509351
# 3               91.28         23869.415656                   12.479830
# 4               86.29         12322.938529                   98.228786
# 7               73.15         11823.686150                   10.988425
#
#   cluster_0 cluster_1 cluster_2 cluster_3
# 1     False     False      True     False
# 2     False     False      True     False
# 3     False     False      True     False
# 4     False     False      True     False
# 7      True     False     False     False

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(6,4))
sns.scatterplot(data=df,
                x='emendas_pix_per_capita_partido_prefeito_eleito',
                y='porcentagem_votos_validos_2024',
                alpha=0.5)
plt.xlabel('Emendas PIX per capita')
plt.ylabel('Votos válidos (proporção)')
plt.title('Distribuição dos dados')
plt.show()

# %%
formula = 'porcentagem_votos_validos_2024 ~ emendas_pix_per_capita_partido_prefeito_eleito + C(sigla_partido_prefeito_eleito) + cluster_0 + cluster_1 + cluster_2 + cluster_3'
ols_res = smf.ols(formula, data=df).fit(cov_type='HC3')
print(ols_res.summary())
# Out:
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     porcentagem_votos_validos_2024   R-squared:                       0.053
# Model:                                        OLS   Adj. R-squared:                  0.044
# Method:                             Least Squares   F-statistic:                     1339.
# Date:                            Tue, 17 Jun 2025   Prob (F-statistic):               0.00
# Time:                                    20:52:42   Log-Likelihood:                 1691.3
# No. Observations:                            2307   AIC:                            -3339.
# Df Residuals:                                2285   BIC:                            -3212.
# Df Model:                                      21
# Covariance Type:                              HC3
# =====================================================================================================================
#                                                         coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------
# Intercept                                             0.5219      0.018     29.699      0.000       0.487       0.556
# C(sigla_partido_prefeito_eleito)[T.CIDADANIA]         0.1175      0.084      1.405      0.160      -0.046       0.281
# C(sigla_partido_prefeito_eleito)[T.MDB]              -0.0260      0.018     -1.459      0.145      -0.061       0.009
# C(sigla_partido_prefeito_eleito)[T.NOVO]             -0.0561     43.667     -0.001      0.999     -85.641      85.529
# C(sigla_partido_prefeito_eleito)[T.PDT]              -0.0171      0.021     -0.813      0.416      -0.058       0.024
# C(sigla_partido_prefeito_eleito)[T.PL]               -0.0448      0.019     -2.405      0.016      -0.081      -0.008
# C(sigla_partido_prefeito_eleito)[T.PODE]             -0.0264      0.030     -0.895      0.371      -0.084       0.031
# C(sigla_partido_prefeito_eleito)[T.PP]               -0.0365      0.018     -2.063      0.039      -0.071      -0.002
# C(sigla_partido_prefeito_eleito)[T.PRD]              -0.0055      0.032     -0.174      0.862      -0.068       0.057
# C(sigla_partido_prefeito_eleito)[T.PSB]              -0.0209      0.021     -0.979      0.328      -0.063       0.021
# C(sigla_partido_prefeito_eleito)[T.PSD]              -0.0213      0.018     -1.175      0.240      -0.057       0.014
# C(sigla_partido_prefeito_eleito)[T.PSDB]             -0.0159      0.021     -0.754      0.451      -0.057       0.026
# C(sigla_partido_prefeito_eleito)[T.PT]               -0.0496      0.019     -2.546      0.011      -0.088      -0.011
# C(sigla_partido_prefeito_eleito)[T.PV]               -0.0550      0.072     -0.768      0.443      -0.195       0.085
# C(sigla_partido_prefeito_eleito)[T.REDE]             -0.0767      1.004     -0.076      0.939      -2.045       1.892
# C(sigla_partido_prefeito_eleito)[T.REPUBLICANOS]     -0.0206      0.019     -1.072      0.284      -0.058       0.017
# C(sigla_partido_prefeito_eleito)[T.SOLIDARIEDADE]    -0.0152      0.025     -0.605      0.545      -0.065       0.034
# C(sigla_partido_prefeito_eleito)[T.UNIÃO]            -0.0205      0.018     -1.109      0.267      -0.057       0.016
# cluster_0[T.True]                                     0.1321      0.012     11.034      0.000       0.109       0.156
# cluster_1[T.True]                                     0.1356      0.040      3.350      0.001       0.056       0.215
# cluster_2[T.True]                                     0.0943      0.012      7.889      0.000       0.071       0.118
# cluster_3[T.True]                                     0.1599      0.022      7.343      0.000       0.117       0.203
# emendas_pix_per_capita_partido_prefeito_eleito     5.674e-07   1.94e-07      2.925      0.003    1.87e-07    9.48e-07
# ==============================================================================
# Omnibus:                       85.650   Durbin-Watson:                   2.015
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               94.489
# Skew:                           0.492   Prob(JB):                     3.03e-21
# Kurtosis:                       3.120   Cond. No.                     9.93e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [2] The smallest eigenvalue is 1.44e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# e:\Learning\TCC-MBA\.venv\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 22, but rank is 21
#   warnings.warn('covariance of constraints does not have full '

# %%
p_val = ols_res.pvalues.get('emendas_pix_per_capita_partido_prefeito_eleito', 1)
coef = ols_res.params.get('emendas_pix_per_capita_partido_prefeito_eleito', float('nan'))
if p_val < 0.05:
    direction = 'positiva' if coef > 0 else 'negativa'
    print(f'O efeito das Emendas PIX per capita é {direction} e estatisticamente significativo (coef={coef:.3f}, p={p_val:.3f})')
else:
    print(f'Nenhuma associação significativa encontrada (coef={coef:.3f}, p={p_val:.3f})')
# Out:
# O efeito das Emendas PIX per capita é positiva e estatisticamente significativo (coef=0.000, p=0.003)

# %%
# Modelo nulo
null_md = smf.mixedlm('porcentagem_votos_validos_2024 ~ 1', df, groups=df['sigla_partido_prefeito_eleito']).fit()

# Interceptos aleatórios
ri_md = smf.mixedlm('porcentagem_votos_validos_2024 ~ emendas_pix_per_capita_partido_prefeito_eleito',
                    df, groups=df['sigla_partido_prefeito_eleito']).fit()

# Intercepto e inclinação aleatórios
ris_md = smf.mixedlm('porcentagem_votos_validos_2024 ~ emendas_pix_per_capita_partido_prefeito_eleito',
                     df, groups=df['sigla_partido_prefeito_eleito'],
                     re_formula='~emendas_pix_per_capita_partido_prefeito_eleito').fit()

# Modelo completo com clusters
full_md = smf.mixedlm('porcentagem_votos_validos_2024 ~ emendas_pix_per_capita_partido_prefeito_eleito + cluster_0 + cluster_1 + cluster_2 + cluster_3',
                      df, groups=df['sigla_partido_prefeito_eleito'],
                      re_formula='~emendas_pix_per_capita_partido_prefeito_eleito').fit()

for lbl, m in [('Nulo', null_md), ('RI', ri_md), ('RI+RS', ris_md), ('Completo', full_md)]:
    print('', lbl)
    display(m.summary())
# Out:
# e:\Learning\TCC-MBA\.venv\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# e:\Learning\TCC-MBA\.venv\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# e:\Learning\TCC-MBA\.venv\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# e:\Learning\TCC-MBA\.venv\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# e:\Learning\TCC-MBA\.venv\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# e:\Learning\TCC-MBA\.venv\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# e:\Learning\TCC-MBA\.venv\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# e:\Learning\TCC-MBA\.venv\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# e:\Learning\TCC-MBA\.venv\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# e:\Learning\TCC-MBA\.venv\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with cg
#   warnings.warn(
#  Nulo
# e:\Learning\TCC-MBA\.venv\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# e:\Learning\TCC-MBA\.venv\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# e:\Learning\TCC-MBA\.venv\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 2708.486170
#   warnings.warn(msg, ConvergenceWarning)
# e:\Learning\TCC-MBA\.venv\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# e:\Learning\TCC-MBA\.venv\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                    Mixed Linear Model Regression Results
# ============================================================================
# Model:            MixedLM Dependent Variable: porcentagem_votos_validos_2024
# No. Observations: 2307    Method:             REML
# No. Groups:       18      Scale:              0.0141
# Min. group size:  1       Log-Likelihood:     1628.6773
# Max. group size:  416     Converged:          Yes
# Mean group size:  128.2
# --------------------------------------------------------------------------------
#                   Coef.     Std.Err.        z        P>|z|     [0.025     0.975]
# --------------------------------------------------------------------------------
# Intercept         0.618        0.005     134.362     0.000      0.609      0.627
# Group Var         0.000        0.001
# ============================================================================
#
# """
#  RI
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                           Mixed Linear Model Regression Results
# =========================================================================================
# Model:                 MixedLM     Dependent Variable:     porcentagem_votos_validos_2024
# No. Observations:      2307        Method:                 REML
# No. Groups:            18          Scale:                  0.0140
# Min. group size:       1           Log-Likelihood:         1628.0716
# Max. group size:       416         Converged:              Yes
# Mean group size:       128.2
# -----------------------------------------------------------------------------------------
#                                                Coef. Std.Err.    z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------------------------------
# Intercept                                      0.608    0.005 124.687 0.000  0.598  0.617
# emendas_pix_per_capita_partido_prefeito_eleito 0.000    0.000   5.379 0.000  0.000  0.000
# Group Var                                      0.000    0.001
# =========================================================================================
#
# """
#  RI+RS
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                                 Mixed Linear Model Regression Results
# =====================================================================================================
# Model:                     MixedLM         Dependent Variable:         porcentagem_votos_validos_2024
# No. Observations:          2307            Method:                     REML
# No. Groups:                18              Scale:                      0.0139
# Min. group size:           1               Log-Likelihood:             1448.6947
# Max. group size:           416             Converged:                  Yes
# Mean group size:           128.2
# -----------------------------------------------------------------------------------------------------
#                                                            Coef. Std.Err.    z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                                                  0.603    0.003 191.234 0.000  0.597  0.609
# emendas_pix_per_capita_partido_prefeito_eleito             0.000    0.013   0.000 1.000 -0.026  0.026
# Group Var                                                  0.000    0.000
# Group x emendas_pix_per_capita_partido_prefeito_eleito Cov 0.000    0.001
# emendas_pix_per_capita_partido_prefeito_eleito Var         0.003
# =====================================================================================================
#
# """
#  Completo
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                                      Mixed Linear Model Regression Results
# ===============================================================================================================
# Model:                         MixedLM            Dependent Variable:            porcentagem_votos_validos_2024
# No. Observations:              2307               Method:                        REML
# No. Groups:                    18                 Scale:                         0.0135
# Min. group size:               1                  Log-Likelihood:                1552.8616
# Max. group size:               416                Converged:                     No
# Mean group size:               128.2
# ---------------------------------------------------------------------------------------------------------------
#                                                            Coef.   Std.Err.    z   P>|z|    [0.025     0.975]
# ---------------------------------------------------------------------------------------------------------------
# Intercept                                                   0.416 349525.333 0.000 1.000 -685056.649 685057.481
# cluster_0[T.True]                                           0.210 349525.333 0.000 1.000 -685056.855 685057.275
# cluster_1[T.True]                                           0.217 349525.333 0.000 1.000 -685056.848 685057.282
# cluster_2[T.True]                                           0.173 349525.333 0.000 1.000 -685056.892 685057.238
# cluster_3[T.True]                                           0.239 349525.333 0.000 1.000 -685056.826 685057.304
# emendas_pix_per_capita_partido_prefeito_eleito              0.000      0.000 0.001 0.999      -0.000      0.000
# Group Var                                                   0.001
# Group x emendas_pix_per_capita_partido_prefeito_eleito Cov -0.000
# emendas_pix_per_capita_partido_prefeito_eleito Var          0.000
# ===============================================================================================================
#
# """

# %%
p_val = full_md.pvalues.get('emendas_pix_per_capita_partido_prefeito_eleito', 1)
coef = full_md.params.get('emendas_pix_per_capita_partido_prefeito_eleito', float('nan'))
if p_val < 0.05:
    direction = 'positiva' if coef > 0 else 'negativa'
    print(f'No modelo multinível completo o efeito é {direction} e estatisticamente significativo (coef={coef:.3f}, p={p_val:.3f})')
else:
    print(f'No modelo multinível completo não há associação significativa (coef={coef:.3f}, p={p_val:.3f})')
# Out:
# No modelo multinível completo não há associação significativa (coef=0.000, p=0.999)
